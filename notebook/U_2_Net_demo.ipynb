# %% [markdown]
# Before starting, please check runtime setting is GPU !!!

# %% [markdown]
# # Clone repository

# %%
# !git clone https://github.com/NathanUA/U-2-Net.git
# Out:
# Cloning into 'U-2-Net'...
# remote: Enumerating objects: 401, done.
# remote: Total 401 (delta 0), reused 0 (delta 0), pack-reused 401
# Receiving objects: 100% (401/401), 20.30 MiB | 45.20 MiB/s, done.
# Resolving deltas: 100% (154/154), done.

# %%
# %cd U-2-Net
# Out:
# /content/U-2-Net

# %% [markdown]
# # Download model weights from google drive

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.6/dist-packages (3.6.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from gdown) (4.41.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (3.0.4)

# %%
import os
import gdown

os.makedirs('./saved_models/u2net', exist_ok=True)
os.makedirs('./saved_models/u2net_portrait', exist_ok=True)

gdown.download('https://drive.google.com/uc?id=1ao1ovG1Qtx4b7EoskHXmi2E9rp5CHLcZ',
    './saved_models/u2net/u2net.pth',
    quiet=False)

gdown.download('https://drive.google.com/uc?id=1IG3HdpcRiDoWNookbncQjeaPN28t90yW',
    './saved_models/u2net_portrait/u2net_portrait.pth',
    quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ao1ovG1Qtx4b7EoskHXmi2E9rp5CHLcZ
# To: /content/U-2-Net/saved_models/u2net/u2net.pth
# 176MB [00:01, 162MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1IG3HdpcRiDoWNookbncQjeaPN28t90yW
# To: /content/U-2-Net/saved_models/u2net_portrait/u2net_portrait.pth
# 176MB [00:01, 110MB/s]
# './saved_models/u2net_portrait/u2net_portrait.pth'

# %% [markdown]
# # Run

# %%
# !python u2net_portrait_demo.py
# Out:
# Number of images:  11
# --------------------------
# inferencing  0 / 11 ./test_data/test_portrait_images/your_portrait_im/smile.jpg
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2952: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3063: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# --------------------------
# inferencing  1 / 11 ./test_data/test_portrait_images/your_portrait_im/GalGadot.jpg
# --------------------------
# inferencing  2 / 11 ./test_data/test_portrait_images/your_portrait_im/kid3.jpg
# --------------------------
# inferencing  3 / 11 ./test_data/test_portrait_images/your_portrait_im/kid2.jpg
# --------------------------
# inferencing  4 / 11 ./test_data/test_portrait_images/your_portrait_im/man5.jpg
# --------------------------
# inferencing  5 / 11 ./test_data/test_portrait_images/your_portrait_im/man.jpg
# --------------------------
# inferencing  6 / 11 ./test_data/test_portrait_images/your_portrait_im/kid1.jpg
# --------------------------
# inferencing  7 / 11 ./test_data/test_portrait_images/your_portrait_im/man2.jpg
# --------------------------
# inferencing  8 / 11 ./test_data/test_portrait_images/your_portrait_im/man4.jpg
# --------------------------
# inferencing  9 / 11 ./test_data/test_portrait_images/your_portrait_im/guliNazha3.jpg
# --------------------------
# inferencing  10 / 11 ./test_data/test_portrait_images/your_portrait_im/Xuebin-10.jpeg

# %%
from IPython.display import Image,display_jpeg
display_jpeg(Image('./test_data/test_portrait_images/your_portrait_im/kid2.jpg'))

# %%
from IPython.display import Image,display_png
display_png(Image('/content/U-2-Net/test_data/test_portrait_images/your_portrait_results/kid2.png'))
